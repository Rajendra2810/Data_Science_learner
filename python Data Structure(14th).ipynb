# %% [raw]
# Python Data Structure
#
# what is differnce between data type ve data structure
#
# datatype=== user assign only 1 value
#  a= 5 | b= 5.5 = "int"
# b = 2, 3 4
#
# Data structure --  -- User assign more then one value in variable is called data structure
#
#
# a = [2,3,4,5,6,7]
# List
# Tuble
# set
# Dictionary
# Range
#
# what is data type, data structure, matrix, table
#
# Data science == Data + scinece
#
# Data -- number, image, text, image, video
#
# [3]--scaler
# [3/4] ---vertical vecctor
# [3,4] -- Horizontal vector
#
#
# Data structure --- cillection of data types
# matrix -- collection of Data structure
# Table --- collection of rows & column
#
# ====
#
# vector - --collection of scaler element
# Matrix--

# %% [markdown]
# # List Data structure

# %%
1-- []
2-- append() -- Add the value at the end or Last
3-- append() -- Duplicate are there
4--- List is growable
5--- Copy() from one list to another list
6--- clear() is allowed in list
7-- count() number of occurac of the list
8--- extend() we merge the list
9--- Indexinf is allowed in list
10-- nested list allowed
11-- list is mutable or changable

# %%
l = []  #empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l. # . enter Tab show all the

# %%
l.append(10)
l
# Out:
# [10, 10, 10, 10]

# %%
len(l)
# Out:
# 2

# %%
l.append(20)
l
# Out:
# [10, 10, 10, 10, 20]

# %%
l
# Out:
# [10, 10, 10, 10, 20]

# %%
l = [10]
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)    # shift + Tab
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 10, 10]

# %%
l1 = [10, 3.5, True,1+2j, 'Rajendra']
l1
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra']

# %%
l1.append([1,2,3])  # List inside the list is nested List
l1
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 10, 10]
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %% [markdown]
# # .copy()

# %%
l3  = l.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 10, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 10, 10]
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]
# [10, 20, 30, 40, 10, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# True

# %%
id(l) != id(l3)
# Out:
# False

# %%
print(id(l))
print(id(l3))
# Out:
# 2642842152448
# 2642842152448

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 10, 10]
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]
# [10, 20, 30, 40, 10, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# []
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l
# Out:
# []

# %%
l = [10, 20, 30, 40, 10]
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l.count(40)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 10]
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 40, 10, 10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
print(len(l))
print(len(l1))
# Out:
# 11
# 6

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
a1.extend(b1)

# %%
a1.extend(b1)

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 10, 10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l.index(20)
# Out:
# 1

# %%
l.index(1+2j)
# Out:
# 8

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[5]
# Out:
# [1, 2, 3]

# %%
l1[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 l1[6]
#
# IndexError: list index out of range

# %%
l1[4]
# Out:
# 'Rajendra'

# %%
l1[2:3]
# Out:
# [True]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[3:]
# Out:
# [(1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'Rajendra']

# %%
l1[-3]
# Out:
# (1+2j)

# %%
l1[-3:]
# Out:
# [(1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[:-3]
# Out:
# [10, 3.5, True]

# %%
l1[::-1]
# Out:
# [[1, 2, 3], 'Rajendra', (1+2j), True, 3.5, 10]

# %%
l1[::-2]
# Out:
# [[1, 2, 3], (1+2j), 3.5]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[4]
# Out:
# 'Rajendra'

# %%
print(l1[4][0])
# Out:
# R

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
print(l1[4][6])
print(l1[4][7])
# Out:
# R
# a
# j
# e
# n
# d
# r
# a

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 100

# %%
l1
# Out:
# [100, 3.5, True, (1+2j), 'Rajendra', [1, 2, 3]]
