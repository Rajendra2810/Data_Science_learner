# %%
13th==
1 = framework --- set of rules, Package,
2 = package --- Collection of module
3 = module --- Collection of Function
4 = Function -- 
5 = Math module
6 = input()

   Inbuild function -- print(),Id(), type()
    user define function


Mechine learning fremawork --  sklearn, xgboost, lgbm
AI(NLP framework) -- NLTK, spacy
Deep learning framework --- Tensflow, keras,
Computer vission framework- -- opencv, yolo, mediapipe
generative ai framework -- lancchain, langgraph, langsmith
agentic ai frame work-   crew ai,phi agno, autogen, smolagent

# %%
25
# Out:
# 25

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)  #(lower)
# Out:
# 3

# %%
math.ceil(3.5) #(upper)
# Out:
# 4

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.9)
# Out:
# 5

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
m.floor(3.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 m.floor(3.4)
#
# NameError: name 'm' is not defined

# %%
import math as m
print(m.floor(3.4))
print(m.ceil(3.4))
print(m.pow(2,4))
# Out:
# 3
# 4
# 16.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
from math import pow, floor, ceil, sqrt
print(floor(3.4))
print(ceil(3.4)) # code optimization
print(pow(2,4))
print(sqrt(10))
# Out:
# 3
# 4
# 16.0
# 3.1622776601683795

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  exit
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
from math import *
print(floor(3.4))
print(ceil(3.4)) # code optimization
print(pow(2,4))
print(sqrt(10))
# Out:
# 3
# 4
# 16.0
# 3.1622776601683795

# %% [markdown]
# From keyword
# import keyword
# as keyword

# %% [markdown]
# # input()

# %%
x = input()
x
# Out:
#  5
# '5'

# %%
x= input()
y = input()

z = x + y
print(z)
# Out:
#  5
#  3
# 53

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = int(input())
y = int(input())

z = x + y
print(z)
# Out:
#  5
#  3
# 8

# %%
x1 = input('Enter the 1st number')
y1 = input('Enter the 2nd number')

z1 = x1 + y1
print(z1)
# Out:
# Enter the 1st number 5
# Enter the 2nd number 7
# 57

# %%
type(x1)
# Out:
# str

# %%
type(y1)
# Out:
# str

# %%
x1 = input('Enter the 1st number')
a1 = int(x1)
y1 = input('Enter the 2nd number')
b1 = int(y1)

z1 = a1 + b1
print(z1)
# Out:
# Enter the 1st number 99
# Enter the 2nd number 87
# 186

# %%
type(a1)
# Out:
# int

# %%
type(x1)
# Out:
# str

# %%
type(z1)
# Out:
# int

# %%
x2 = int(input("Enter the 1st number"))
y2 = int(input("Enter the 2nd number"))

z2 = x2 + y2
z2
# Out:
# Enter the 1st number 65
# Enter the 2nd number 5
# 70

# %% [markdown]
# # Take input from user in char format

# %%
ch = input('enter the char')
print(ch)
# Out:
# enter the char Rajendra Sahoo
# Rajendra Sahoo

# %%
print(ch[0])
# Out:
# R

# %%
print(ch[0])
print(ch[1])
print(ch[2])
print(ch[3])
print(ch[4])
print(ch[5])
print(ch[6])
print(ch[7])
print(ch[8])
print(ch[9])
print(ch[10])
print(ch[11])
print(ch[12])
print(ch[13])
# Out:
# R
# a
# j
# e
# n
# d
# r
# a
#
# S
# a
# h
# o
# o

# %%
print(ch[0:14])
# Out:
# Rajendra Sahoo

# %%
print(ch[0::])
# Out:
# Rajendra Sahoo

# %%
print(ch[0::6])
# Out:
# Rro

# %%
print(ch[0::5])
# Out:
# Rda

# %% [markdown]
# # EVAL function ussinng input

# %%
result = eval(input("Enter an expr"))
print(result)
# Out:
# Enter an expr 6+5-2
# 9
