# %% [raw]
# === 7th
#
#
# before we build ml model
# 	we need some foundation techniqu e-14
#
# python function works
# data anlayss library
# EDA -- Explaratory data analysis
#
# after completed these foundation python + sql + eda + stats + data analyss
# 	we will build ml prediction model
#
#
# EDA is the paraent of ml
# if you not understand eda then ml is not clered
# if ml is not clear then mlops & cicd
#
#
# database, -- collection of table
# server - collection of database
# table -- collection of rows * Columns
# cloud -- dta store in datacenter
#
# hyder what cloud -- what is cloud datacenter
# to setup datacenter --
#
# ---
# EDA (Explaratory Data Analysis) TECHNIQUE -->
# --
# 1- variable identificaiton
# 2- univariate anlaysis
# 3- bivariate analysis
# 4- outlier treatment
# 5- missing value treatment
# 6- variable transformation
# 7- variable createion
#
# Above 7 technique is required to cover raw data - clean data
#
# 1- variable identification
# 		excel sheet == dataset
# 		attribute == columns = variable
#
# family there 4 attribute 4 memeber
# 			father -- govt emplye , house emi , keds fee, land loan (depdendent variable) = y
# 			mom -- housewife (independent variable) = x1
# 			brother -- 4th grade (independent variable ) = x2
# 			sister -- 3rd grade (indendent variable) = x3
#
# math equation == (y =x1 + x2 + x3) -- multiple linear regreassion algoriytm
#
# dependetn varaible == target attribute == predicted variable == y
# independent variable == non target attribute == non predicted variable --
#
#
# machine learning --
# 	regression - if dependent variable is continuous variable thati is regression concept
# 	classification -- if dependent varibel is binary
# 	clustering -- there no dpdent variable if the data is discreate (clusting means - group)
# ---
# what is continuous variable -->
# --
# gold price -- continus
# petrol price -- continu
# electricity monthly
# ev car sale -- continur
# stock   -- continuous
# house price
# land price
# weather
#
# To build this type of project we need to implement REGRESSION ALGORITHM
# 1- simple linear regression
# 2- multiple linear regression
# 3- graident descend | stocastic gradient descend | batch gradient descend
# 4- regulariozation ( l1, l2) -- lasso regression ( l1) & ridge regression (l2)
# 5- k nearest neighbour regressor
# 6- decission tree regresion
# 7- random forest regression
# 8- xgboost regression
# 9- lgbm regression
# 10- artificial neural network regression
# 11 - time series regression
# 12- svr (support vetor regressor)
#
# ====
# classification  - dv is binary or category
# 	win or loose
# 	profit or lose
# 	cat or dog
# 	+Ve or -ve
# 	high or low
#
# classfication algorithm
#
# 1-logistic regression
# 2- svm (support vector machine)
# 3- knn classifier
# 4- decission tree classifier
# 5- naive bayes classifier
# 6- random forest classifier
# 7- xtream gradient boosting (xgboost) classifier
# 8- light gbm ( lgbm ) classifier
# 9- ann classifier
# ===
# clustring   -- grouping (data discreate
# ===
# 1=
#
# continuous data -- keep on incres or decreae ( ex - gold price , stock price )
# vs
# binary data -- (w | l, p | l)
# vs
# discrete data --- point where it stops ( student score stops at 100 )
# 		can you finalt top rank student >95 -- 1 gropu
# 		score percener (90- 97%) -- group 2
# 		score 80-90 -- group 3
# 		score 70- 80-- group 4
# 		score -- >30- 60 --- group 5
#
# overall we make 5 clauster  -- using cluder we can find out best candidate
# claustring algorithnm
# 1- pca (principal component analysis)
# 2- k-means
# 3- hierarchical
# 5- dbscan
# ===  ml will finished
#
#
# why stat will come hear
#
# after we build regression model -- we need to test the model model is accuracy or not
# 	performance measure --
# 		r2, adjusted r2, mae, mse, rmse
#
# confusion matrix ---
#
#
# 1- variable identificaiton
# 		dv -- alwasy 1  ( y)
# 		iv -- alwasy many ( x1, x2, x3 ----)
# 		relavante attribute
# 		non relavant attribute
#
# ml worflow or ml pipeline 1sst conpcet every select right relavent attribute to get more accuracy
#
# if model build by irrelavat attribute then multicolenarity problem occurace
# also we called as overfitting
# if ml model overfit -- model accurcay will decrease -- high errro =- model cannot deploye
# 	website cannot build -- compnay doesn launch the website -- business will loss
#
#
# 2- univariate anlalys s-- plat graph using 1 variable
#
# 3- bivariate analysis -- plot the greph using 2 variable
# 		corelation -- relation amoug 2 attribute is called corelation
# 				+ve corr is
# 				-ve corr
# 				0 corr
#
# range of corr is -1 to 1
# +ve corr - 0 to 1
# -ve corr - -1 to 0
# no corr - 0
#
#
# 1- variable identifiction
# 2- univariate
# 3- bivaraate & Corelation
# 4- outlier treate
#
# ollama + streamlit --

# %%
5 - Missing value treatment
In dataset if numberical value is missing -- then mean | median | mode statige

In dataset if categorical value is missing -- then mode statige apply

6 & 7
6---variable imputation also called transformer
7--- Variable creation
